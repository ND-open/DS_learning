# %%
import pydotplus
import pandas as pd
import numpy as np
from sklearn import datasets
dir(datasets)
iris = datasets.load_iris()

# %%
from sklearn.tree import DecisionTreeClassifier # Regressor
tree_mod = DecisionTreeRegressor(random_state = 1)

# %%
# X = pd.DataFrame.from_dict(iris, orient='index')
# X.transpose().head()
# X0 = pd.DataFrame(data= np.c_[iris['data'], iris['target']],
#                      columns= iris['feature_names'] + ['target'])
# X0.head()

# y = X0['target']
# X = X0.iloc[:,1:4].head()

df = pd.DataFrame(iris.data, columns=iris.feature_names)
df.head()
df.shape
# Out:
# (150, 4)

# %% [markdown]
# J'entraîne mon modèle sur tout l'échantillon (pas bien) :

# %%
# X.shape()
tree_mod.fit(df, iris.target)
# iris
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=1, splitter='best')

# %%
from sklearn.externals.six import StringIO  
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus
dot_data = StringIO()
export_graphviz(tree_mod, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())
